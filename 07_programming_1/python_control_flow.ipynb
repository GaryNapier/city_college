# %% [markdown]
# # Control-flow in Python
#
# Now that we have out types of basic object (numbers, strings etc) and collection types (sets, lists, dicts, tuples), we want to do things with them.
#
# i.e. start programming!
